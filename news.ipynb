# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('news.csv')

# %%
df
# Out:
#                      author                      published  \
# 0         Barracuda Brigade  2016-10-26T21:41:00.000+03:00
# 1      reasoning with facts  2016-10-29T08:47:11.259+03:00
# 2         Barracuda Brigade  2016-10-31T01:41:49.479+02:00
# 3                    Fed Up  2016-11-01T05:22:00.000+02:00
# 4                    Fed Up  2016-11-01T21:56:00.000+02:00
# ...                     ...                            ...
# 12994             replaceme  2016-10-26T23:58:00.000+03:00
# 12995              Freedumb  2016-10-27T00:02:00.000+03:00
# 12996    major major maj...  2016-10-27T00:06:00.000+03:00
# 12997            beemasters  2016-10-27T00:09:00.000+03:00
# 12998     i&#039;m-confused  2016-10-27T00:09:00.000+03:00
#
#                                                    title  Unnamed: 3  \
# 0      Muslims BUSTED: They Stole Millions In Gov’t B...         NaN
# 1      Re: Why Did Attorney General Loretta Lynch Ple...         NaN
# ...

# %%
df.shape
# Out:
# (12999, 6)

# %%
df.columns
# Out:
# Index(['author', 'published', 'title', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# author         2424
# published         0
# title           680
# Unnamed: 3    12999
# Unnamed: 4    12999
# Unnamed: 5    12999
# dtype: int64

# %%
df.drop(columns='Unnamed: 5', axis=1, inplace=True)

# %%
df
# Out:
#                      author                      published  \
# 0         Barracuda Brigade  2016-10-26T21:41:00.000+03:00
# 1      reasoning with facts  2016-10-29T08:47:11.259+03:00
# 2         Barracuda Brigade  2016-10-31T01:41:49.479+02:00
# 3                    Fed Up  2016-11-01T05:22:00.000+02:00
# 4                    Fed Up  2016-11-01T21:56:00.000+02:00
# ...                     ...                            ...
# 12994             replaceme  2016-10-26T23:58:00.000+03:00
# 12995              Freedumb  2016-10-27T00:02:00.000+03:00
# 12996    major major maj...  2016-10-27T00:06:00.000+03:00
# 12997            beemasters  2016-10-27T00:09:00.000+03:00
# 12998     i&#039;m-confused  2016-10-27T00:09:00.000+03:00
#
#                                                    title
# 0      Muslims BUSTED: They Stole Millions In Gov’t B...
# 1      Re: Why Did Attorney General Loretta Lynch Ple...
# 2      BREAKING: Weiner Cooperating With FBI On Hilla...
# ...

# %%
df.drop_duplicates(subset='author', keep=False, inplace=True)

# %%
df
# Out:
#                      author                      published  \
# 1      reasoning with facts  2016-10-29T08:47:11.259+03:00
# 55              Branko Mali  2016-11-25T14:33:14.332+02:00
# 80              pak alresky  2016-10-28T11:58:00.000+03:00
# 119           IBU SUMIATUNG  2016-10-31T12:28:00.000+02:00
# 147             Steve smith  2016-11-01T22:22:00.000+02:00
# ...                     ...                            ...
# 12994             replaceme  2016-10-26T23:58:00.000+03:00
# 12995              Freedumb  2016-10-27T00:02:00.000+03:00
# 12996    major major maj...  2016-10-27T00:06:00.000+03:00
# 12997            beemasters  2016-10-27T00:09:00.000+03:00
# 12998     i&#039;m-confused  2016-10-27T00:09:00.000+03:00
#
#                                                    title
# 1      Re: Why Did Attorney General Loretta Lynch Ple...
# 55     Hell Comes to Frogtown: Alt Right and Triumph ...
# 80                                                   NaN
# ...

# %%
df1=df.dropna()
df1
# Out:
#                      author                      published  \
# 1      reasoning with facts  2016-10-29T08:47:11.259+03:00
# 55              Branko Mali  2016-11-25T14:33:14.332+02:00
# 160                  Peeple  2016-10-27T00:53:00.000+03:00
# 162             seentoomuch  2016-10-26T21:13:00.000+03:00
# 163                  vlawde  2016-10-27T02:54:39.811+03:00
# ...                     ...                            ...
# 12381          Jason Bermas  2016-11-06T20:25:29.050+02:00
# 12509             Old_Logan  2016-11-09T20:06:00.000+02:00
# 12595       Conover Kennard  2016-11-12T07:00:00.000+02:00
# 12806         administrator  2016-10-27T13:29:57.926+03:00
# 12910     George Washington  2016-10-26T23:53:49.879+03:00
#
#                                                    title
# 1      Re: Why Did Attorney General Loretta Lynch Ple...
# 55     Hell Comes to Frogtown: Alt Right and Triumph ...
# 160                                    We Know The Truth
# ...

# %%
df1.head()
# Out:
#                    author                      published  \
# 1    reasoning with facts  2016-10-29T08:47:11.259+03:00
# 55            Branko Mali  2016-11-25T14:33:14.332+02:00
# 160                Peeple  2016-10-27T00:53:00.000+03:00
# 162           seentoomuch  2016-10-26T21:13:00.000+03:00
# 163                vlawde  2016-10-27T02:54:39.811+03:00
#
#                                                  title
# 1    Re: Why Did Attorney General Loretta Lynch Ple...
# 55   Hell Comes to Frogtown: Alt Right and Triumph ...
# 160                                  We Know The Truth
# 162  Found this nugget in Podesta files Fastwalkers...
# 163                             EMP event forthcoming?

# %%
df1.tail()
# Out:
#                   author                      published  \
# 12381       Jason Bermas  2016-11-06T20:25:29.050+02:00
# 12509          Old_Logan  2016-11-09T20:06:00.000+02:00
# 12595    Conover Kennard  2016-11-12T07:00:00.000+02:00
# 12806      administrator  2016-10-27T13:29:57.926+03:00
# 12910  George Washington  2016-10-26T23:53:49.879+03:00
#
#                                                    title
# 12381     The Sex Scandal That Could Change The Election
# 12509  National Attention On Ayotte - Hassan (*NH) Se...
# 12595  Trumpians Mistake Lupus Patient’s Head Coverin...
# 12806  WikiLeaks: Hillary Admits Clinton Foundation D...
# 12910  Fact Check: Trump Is Right that Clinton Might ...

# %%
df1.describe()
# Out:
#                    author                      published  \
# count                1043                           1043
# unique               1043                            975
# top     سعيد هلال الشريفي  2016-11-01T02:00:00.000+02:00
# freq                    1                              9
#
#                                  title
# count                             1043
# unique                            1042
# top     The Pathologization of Dissent
# freq                                 2

# %%
df1.reindex()
# Out:
#                      author                      published  \
# 1      reasoning with facts  2016-10-29T08:47:11.259+03:00
# 55              Branko Mali  2016-11-25T14:33:14.332+02:00
# 160                  Peeple  2016-10-27T00:53:00.000+03:00
# 162             seentoomuch  2016-10-26T21:13:00.000+03:00
# 163                  vlawde  2016-10-27T02:54:39.811+03:00
# ...                     ...                            ...
# 12381          Jason Bermas  2016-11-06T20:25:29.050+02:00
# 12509             Old_Logan  2016-11-09T20:06:00.000+02:00
# 12595       Conover Kennard  2016-11-12T07:00:00.000+02:00
# 12806         administrator  2016-10-27T13:29:57.926+03:00
# 12910     George Washington  2016-10-26T23:53:49.879+03:00
#
#                                                    title
# 1      Re: Why Did Attorney General Loretta Lynch Ple...
# 55     Hell Comes to Frogtown: Alt Right and Triumph ...
# 160                                    We Know The Truth
# ...

# %%
df1.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-806896f8730b> in <module>
# ----> 1 df1.reset_index(inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4692                 # to ndarray and maybe infer different dtype
#    4693                 level_values = _maybe_casted_values(lev, lab)
# -> 4694                 new_obj.insert(0, name, level_values)
#    4695
#    4696         new_obj.index = new_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3574         self._ensure_valid_index(value)
#    3575         value = self._sanitize_column(column, value, broadcast=False)
# -> 3576         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3577
# ...

# %%
df1
# Out:
#       level_0  index                author                      published  \
# 0           0      1  reasoning with facts  2016-10-29T08:47:11.259+03:00
# 1           1     55           Branko Mali  2016-11-25T14:33:14.332+02:00
# 2           2    160                Peeple  2016-10-27T00:53:00.000+03:00
# 3           3    162           seentoomuch  2016-10-26T21:13:00.000+03:00
# 4           4    163                vlawde  2016-10-27T02:54:39.811+03:00
# ...       ...    ...                   ...                            ...
# 1038     1038  12381          Jason Bermas  2016-11-06T20:25:29.050+02:00
# 1039     1039  12509             Old_Logan  2016-11-09T20:06:00.000+02:00
# 1040     1040  12595       Conover Kennard  2016-11-12T07:00:00.000+02:00
# 1041     1041  12806         administrator  2016-10-27T13:29:57.926+03:00
# 1042     1042  12910     George Washington  2016-10-26T23:53:49.879+03:00
#
#                                                   title
# ...

# %%
df1.set_index('level_0',inplace=True)

# %%
df1
# Out:
#                        author                      published  \
# level_0
# 0        reasoning with facts  2016-10-29T08:47:11.259+03:00
# 1                 Branko Mali  2016-11-25T14:33:14.332+02:00
# 2                      Peeple  2016-10-27T00:53:00.000+03:00
# 3                 seentoomuch  2016-10-26T21:13:00.000+03:00
# 4                      vlawde  2016-10-27T02:54:39.811+03:00
# ...                       ...                            ...
# 1038             Jason Bermas  2016-11-06T20:25:29.050+02:00
# 1039                Old_Logan  2016-11-09T20:06:00.000+02:00
# 1040          Conover Kennard  2016-11-12T07:00:00.000+02:00
# 1041            administrator  2016-10-27T13:29:57.926+03:00
# 1042        George Washington  2016-10-26T23:53:49.879+03:00
#
#                                                      title
# level_0
# 0        Re: Why Did Attorney General Loretta Lynch Ple...
# 1        Hell Comes to Frogtown: Alt Right and Triumph ...
# ...

# %%
df1.rename(columns={'level_0': 'Id'})
# Out:
#                        author                      published  \
# level_0
# 0        reasoning with facts  2016-10-29T08:47:11.259+03:00
# 1                 Branko Mali  2016-11-25T14:33:14.332+02:00
# 2                      Peeple  2016-10-27T00:53:00.000+03:00
# 3                 seentoomuch  2016-10-26T21:13:00.000+03:00
# 4                      vlawde  2016-10-27T02:54:39.811+03:00
# ...                       ...                            ...
# 1038             Jason Bermas  2016-11-06T20:25:29.050+02:00
# 1039                Old_Logan  2016-11-09T20:06:00.000+02:00
# 1040          Conover Kennard  2016-11-12T07:00:00.000+02:00
# 1041            administrator  2016-10-27T13:29:57.926+03:00
# 1042        George Washington  2016-10-26T23:53:49.879+03:00
#
#                                                      title
# level_0
# 0        Re: Why Did Attorney General Loretta Lynch Ple...
# 1        Hell Comes to Frogtown: Alt Right and Triumph ...
# ...

# %%
df=df1

# %%
df
# Out:
#                        author                      published  \
# level_0
# 0        reasoning with facts  2016-10-29T08:47:11.259+03:00
# 1                 Branko Mali  2016-11-25T14:33:14.332+02:00
# 2                      Peeple  2016-10-27T00:53:00.000+03:00
# 3                 seentoomuch  2016-10-26T21:13:00.000+03:00
# 4                      vlawde  2016-10-27T02:54:39.811+03:00
# ...                       ...                            ...
# 1038             Jason Bermas  2016-11-06T20:25:29.050+02:00
# 1039                Old_Logan  2016-11-09T20:06:00.000+02:00
# 1040          Conover Kennard  2016-11-12T07:00:00.000+02:00
# 1041            administrator  2016-10-27T13:29:57.926+03:00
# 1042        George Washington  2016-10-26T23:53:49.879+03:00
#
#                                                      title
# level_0
# 0        Re: Why Did Attorney General Loretta Lynch Ple...
# 1        Hell Comes to Frogtown: Alt Right and Triumph ...
# ...

# %%
df.isnull().sum()
# Out:
# author       0
# published    0
# title        0
# dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
import nltk
import os
from nltk.tokenize import word_tokenize
